# %%
import math as mt
import matplotlib.pyplot as plt

# %%
x1=0
x=-0.1066
y=0
x2=0
y=0
i=0
j=0
z=0
a=0
b=0
xp2=0
t=0
yy=0
n=0
dt=0.0003
xl=[]
yl=[]
yyl=[]

# %%
    while t<1000 :
        x=x+y*dt
        y=y+x2*dt
        x2=-1*mt.sin(x)-0.05*y+0.4*mt.cos(0.7*3.1269*t)
        xp2=-1*mt.sin(x)-0.05*yy+0.4*mt.cos(z)
        z=z+2*mt.acos(-1)
        yy=yy+xp2*dt
        t=t+dt
        if t>950:
            xl.append(x)
            yl.append(y)
            yyl.append(yy)
    plt.plot(xl, yl)
    plt.xlabel('x - axis')
    plt.ylabel('y - axis')
    plt.title('Phase')
    plt.show()
    plt.plot(xl, yyl)
    plt.xlabel('x - axis')
    plt.ylabel('y - axis')
    plt.title('Phase')
    plt.show()
